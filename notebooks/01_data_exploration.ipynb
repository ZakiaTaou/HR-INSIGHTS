# %% [markdown]
# # HR-INSIGHTS
#
# ## Data Exploration

# %%
# Importation des bibliothèques

from pathlib import Path

import sys



# -----------------------------------------------------

# Ajouter la racine du projet (HR-INSIGHTS) au PYTHONPATH

# afin de pouvoir importer les modules du dossier src.

# -----------------------------------------------------

PROJECT_ROOT = Path.cwd().parent



if str(PROJECT_ROOT) not in sys.path:

    sys.path.append(str(PROJECT_ROOT))



# -----------------------------------------------------

# Import de la fonction de lecture Excel

# -----------------------------------------------------

from src.data_loader import load_excel

# %%
# Définition du chemin du fichier Excel

# -----------------------------------------------------

DATA_PATH = PROJECT_ROOT / "data" / "raw" / "situation_administrative.xlsx"



# -----------------------------------------------------

# Chargement des données

# -----------------------------------------------------

df = load_excel(DATA_PATH)

# %% [markdown]
# ## Aperçu des données

# %%
# Affichage des 5 premières lignes
df.head()
# Out:
#    N     P.P.R.  Matricule    Noms et Prénoms Date   de  Naissances  \
# 0  1  9077047.0    10316.0      ABARAY Lahcen            1970-12-31
# 1  2  9077033.0    10299.0      ADILA  Miloud            1963-08-02
# 2  3  9077019.0    10283.0      ADMOR Mohamed            1966-12-31
# 3  4  9077016.0    10280.0  AIT JEDDI Mohamed            1966-11-20
# 4  5  9077009.0    10273.0  AL OUATIQ  Latifa            1967-03-15
#
#   Date de recrutement  Date de mise à la retraite  Sexe   C.I.N.  \
# 0           2001-03-30                  2033-12-31    H  JB96972
# 1           1995-11-13                  2026-08-02    H  J209988
# 2           1992-10-12                  2029-12-31    H   JB2440
# 3           1994-02-01                  2029-11-20    H  JB21553
# 4           1995-08-01                  2030-03-15    F  JC11827
#
#   Date de titularisation   ... Echellon Indice       Date d'échelon   \
# 0     2004-10-01 00:00:00  ...        3     779  2022-11-01 00:00:00
# ...

# %% [markdown]
# ## Dimensions du DataFrame

# %%
df.shape
# Out:
# (1093, 24)

# %% [markdown]
# ## Informations générales

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1093 entries, 0 to 1092
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   N                               1093 non-null   int64
#  1   P.P.R.                          1092 non-null   float64
#  2   Matricule                       987 non-null    float64
#  3   Noms et Prénoms                 1093 non-null   str
#  4   Date   de  Naissances           1093 non-null   datetime64[us]
#  5   Date de recrutement             1093 non-null   datetime64[us]
#  6   Date de mise à la retraite      1092 non-null   datetime64[us]
#  7   Sexe                            1093 non-null   str
#  8   C.I.N.                          1093 non-null   str
#  9   Date de titularisation          1044 non-null   object
#  10  N° Affiliation à la C.M.R       985 non-null    object
#  11  Date d'affiliation à la C.M.R.  995 non-null    object
# ...

# %% [markdown]
# ## Colonnes

# %%
df.columns.tolist()
# Out:
# ['N',
#  'P.P.R.',
#  'Matricule',
#  'Noms et Prénoms',
#  'Date   de  Naissances',
#  'Date de recrutement ',
#  'Date de mise à la retraite ',
#  'Sexe',
#  'C.I.N.',
#  'Date de titularisation ',
#  'N° Affiliation à la C.M.R',
#  "Date d'affiliation à la C.M.R.",
#  'Grade',
#  'Echelle',
#  'Echellon',
#  'Indice ',
#  "Date d'échelon ",
#  "n° d'arrêté ",
#  "Date d'arrêté ",
#  'Date de grade ',
#  'Observations',
#  'Unnamed: 21',
#  '@',
#  'Statut']

# %% [markdown]
# ## Valeurs manquantes

# %%
df.isna().sum()
# Out:
# N                                    0
# P.P.R.                               1
# Matricule                          106
# Noms et Prénoms                      0
# Date   de  Naissances                0
# Date de recrutement                  0
# Date de mise à la retraite           1
# Sexe                                 0
# C.I.N.                               0
# Date de titularisation              49
# N° Affiliation à la C.M.R          108
# Date d'affiliation à la C.M.R.      98
# Grade                                0
# Echelle                              0
# Echellon                             0
# Indice                               0
# Date d'échelon                       0
# n° d'arrêté                          9
# Date d'arrêté                        7
# Date de grade                        0
# Observations                      1092
# Unnamed: 21                         39
# @                                 1092
# Statut                            1054
# dtype: int64

# %% [markdown]
# ## Doublons

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Statistiques descriptives

# %%
df.describe(include="all")
# Out:
#                   N        P.P.R.     Matricule    Noms et Prénoms  \
# count   1093.000000  1.092000e+03    987.000000               1093
# unique          NaN           NaN           NaN               1092
# top             NaN           NaN           NaN  AIT AHMED Mohamed
# freq            NaN           NaN           NaN                  2
# mean     547.000000  8.217136e+06  14527.550152                NaN
# min        1.000000  1.767951e+06  10008.000000                NaN
# 25%      274.000000  9.077232e+06  11675.500000                NaN
# 50%      547.000000  9.078086e+06  15380.000000                NaN
# 75%      820.000000  9.078540e+06  16684.500000                NaN
# max     1093.000000  9.078958e+06  18073.000000                NaN
# std      315.666227  2.275839e+06   2505.306364                NaN
#
#              Date   de  Naissances        Date de recrutement   \
# count                         1093                        1093
# ...

# %% [markdown]
# ## Suppression des colonnes inutiles

# %%
from src.data_cleaning import drop_unused_columns

df = drop_unused_columns(df)

df.columns.tolist()
# Out:
# ['N',
#  'P.P.R.',
#  'Matricule',
#  'Noms et Prénoms',
#  'Date   de  Naissances',
#  'Date de recrutement ',
#  'Date de mise à la retraite ',
#  'Sexe',
#  'C.I.N.',
#  'Date de titularisation ',
#  'N° Affiliation à la C.M.R',
#  "Date d'affiliation à la C.M.R.",
#  'Grade',
#  'Echelle',
#  'Echellon',
#  'Indice ',
#  "Date d'échelon ",
#  "n° d'arrêté ",
#  "Date d'arrêté ",
#  'Date de grade ']

# %% [markdown]
# ## Conversion des colonnes de dates

# %%
from src.data_cleaning import convert_date_columns

df = convert_date_columns(df)

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1093 entries, 0 to 1092
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   N                               1093 non-null   int64
#  1   P.P.R.                          1092 non-null   float64
#  2   Matricule                       987 non-null    float64
#  3   Noms et Prénoms                 1093 non-null   str
#  4   Date   de  Naissances           1093 non-null   datetime64[us]
#  5   Date de recrutement             1093 non-null   datetime64[us]
#  6   Date de mise à la retraite      1092 non-null   datetime64[us]
#  7   Sexe                            1093 non-null   str
#  8   C.I.N.                          1093 non-null   str
#  9   Date de titularisation          1043 non-null   datetime64[us]
#  10  N° Affiliation à la C.M.R       985 non-null    object
#  11  Date d'affiliation à la C.M.R.  994 non-null    datetime64[us]
# ...
