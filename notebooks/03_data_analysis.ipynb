# %% [markdown]
# # HR-INSIGHTS
#
# ## Sprint 4 - Data Analysis
#
# ### Objectif
#
# Ce notebook permet de calculer les indicateurs RH (KPI) à partir des données préparées.
#
# Les indicateurs calculés ici seront ensuite utilisés dans le tableau de bord RH.

# %%
# =====================================================
# Configuration du projet
# =====================================================

from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %% [markdown]
# ## 1. Importation des modules

# %%
from src.data_loader import load_excel

from src.data_cleaning import (
    clean_column_names,
    drop_unused_columns,
    convert_date_columns,
)

from src.feature_engineering import apply_feature_engineering

from src.business_metrics import (
    get_total_employees,
    get_gender_distribution,
    get_gender_percentage,
    get_average_age,
    get_average_seniority,
    get_grade_distribution,
    get_scale_distribution,
    get_step_distribution,
    get_retirements_within_years,
    get_retirement_summary,
    get_retirement_by_grade,
    get_retirement_by_gender,
    get_retirement_by_scale,
    
)
from src.visualizations import (
    create_gender_pie_chart,
    create_grade_bar_chart,
    create_scale_bar_chart,
    create_step_bar_chart,
    create_age_histogram,
    create_seniority_histogram,
)

# %% [markdown]
# ## 2. Chargement et préparation des données

# %%
DATA_PATH = PROJECT_ROOT / "data" / "raw" / "situation_administrative.xlsx"

df = load_excel(DATA_PATH)

df = clean_column_names(df)

df = drop_unused_columns(df)

df = convert_date_columns(df)

df = apply_feature_engineering(df)

# %% [markdown]
# ## 3. Vérification des données

# %%
df.head()
# Out:
#    id        ppr  matricule         nom_prenom date_naissance  \
# 0   1  9077047.0    10316.0      ABARAY Lahcen     1970-12-31
# 1   2  9077033.0    10299.0      ADILA  Miloud     1963-08-02
# 2   3  9077019.0    10283.0      ADMOR Mohamed     1966-12-31
# 3   4  9077016.0    10280.0  AIT JEDDI Mohamed     1966-11-20
# 4   5  9077009.0    10273.0  AL OUATIQ  Latifa     1967-03-15
#
#   date_recrutement date_retraite sexe      cin  date_titularisation  ...  \
# 0       2001-03-30    2033-12-31    H  JB96972  2004-10-01 00:00:00  ...
# 1       1995-11-13    2026-08-02    H  J209988  1996-11-13 00:00:00  ...
# 2       1992-10-12    2029-12-31    H   JB2440  1993-10-12 00:00:00  ...
# 3       1994-02-01    2029-11-20    H  JB21553  1995-02-01 00:00:00  ...
# 4       1995-08-01    2030-03-15    F  JC11827  1997-07-01 00:00:00  ...
#
#   date_grade observations unnamed_21   at statut  age anciennete  \
# 0 2017-01-01          NaN    Oubella  NaN    NaN   55         25
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1093 entries, 0 to 1092
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1093 non-null   int64
#  1   ppr                     1092 non-null   float64
#  2   matricule               987 non-null    float64
#  3   nom_prenom              1093 non-null   str
#  4   date_naissance          1093 non-null   datetime64[us]
#  5   date_recrutement        1093 non-null   datetime64[us]
#  6   date_retraite           1092 non-null   datetime64[us]
#  7   sexe                    1093 non-null   str
#  8   cin                     1093 non-null   str
#  9   date_titularisation     1044 non-null   object
#  10  numero_affiliation_cmr  985 non-null    object
#  11  date_affiliation_cmr    995 non-null    object
#  12  grade                   1093 non-null   str
#  13  echelle                 1093 non-null   object
# ...

# %% [markdown]
# ## 4. Nombre total de fonctionnaires

# %%
total_fonctionnaires = get_total_employees(df)

print(f"Nombre total de fonctionnaires : {total_fonctionnaires}")
# Out:
# Nombre total de fonctionnaires : 1093

# %% [markdown]
# ## 5. Répartition des fonctionnaires par sexe

# %%
gender_distribution = get_gender_distribution(df)

gender_distribution
# Out:
# sexe
# H    871
# F    222
# Name: count, dtype: int64

# %% [markdown]
# ## 6. Pourcentage des fonctionnaires par sexe

# %%
gender_percentage = get_gender_percentage(df)

gender_percentage
# Out:
# sexe
# H    79.69
# F    20.31
# Name: proportion, dtype: float64

# %% [markdown]
# ## 7. Âge moyen des fonctionnaires

# %%
average_age = get_average_age(df)

print(f"Âge moyen : {average_age} ans")
# Out:
# Âge moyen : 51.8 ans

# %% [markdown]
# ## 8. Ancienneté moyenne des fonctionnaires

# %%
average_seniority = get_average_seniority(df)

print(f"Ancienneté moyenne : {average_seniority} ans")
# Out:
# Ancienneté moyenne : 24.7 ans

# %% [markdown]
# ## 9. Répartition des fonctionnaires par grade

# %%
grade_distribution = get_grade_distribution(df)

grade_distribution
# Out:
# grade
# Assistant Technique 1°Grade                   510
# Assistant Technique 2°Grade                   141
# Technicien 2°Grade                             88
# Technicien 3°Grade                             88
# Technicien 1°Grade                             54
# Assistant Administratif 1°Grade                43
# Administrateur Principal                       42
# Technicien 4°Grade                             30
# Administrateur 1°Classe                        16
# Administrateur 1°Grade                          9
# Ingénieur en Chef 1°Grade                       9
# Assistant Administratif 2°Grade                 8
# Ingénieur d'Etat 1°Grade                        7
# Assistant Technique Grade Principal             6
# Ingénieur en Chef Grade Principal               6
# Rédacteur 2°Grade                               6
# Ingénieur d'Etat Grade Principal                5
# Administrateur Adjt 1°Classe                    3
# Infirmier Grade Principal                       3
# ...

# %% [markdown]
# ## 10. Répartition des fonctionnaires par échelle

# %%
scale_distribution = get_scale_distribution(df)

scale_distribution
# Out:
# echelle
# 6      149
# 7        1
# 8      583
# 9       97
# 10      99
# 11     163
# EXP      1
# Name: count, dtype: int64

# %% [markdown]
# ## 11. Répartition des fonctionnaires par échelon

# %%
step_distribution = get_step_distribution(df)

step_distribution
# Out:
# echelon
# 1      55
# 2      69
# 3      23
# 4      97
# 5     140
# 6     140
# 7     102
# 8     172
# 9     200
# 10     75
# 11      8
# 12      4
# 13      0
# Name: count, dtype: int64

# %%
retirement_1_year = get_retirements_within_years(df, 1)

retirement_1_year
# Out:
#             nom_prenom                            grade sexe echelle echelon  \
# 0        ADILA  Miloud         Administrateur Principal    H      11       5
# 1      OUCHRIF  Hassan                Rédacteur 2°Grade    H      10      10
# 2        KDIR  Zoubida      Assistant Technique 1°Grade    F       8       7
# 3         SIBOU Lahsen      Assistant Technique 1°Grade    H       8       9
# 4       TOULALI Brahim                Rédacteur 2°Grade    H      10       9
# ..                 ...                              ...  ...     ...     ...
# 120    BENOUCHA Lahsen      Assistant Technique 1°Grade    H       8      10
# 121   OUALLOU Mustapha      Assistant Technique 1°Grade    H       8       8
# 122  ABOUHAM Lahoucine      Assistant Technique 1°Grade    H       8       9
# 123      AKHARAZ Larbi      Assistant Technique 1°Grade    H       8       9
# 124    EL KADIRI Daoud  Assistant Administratif 1°Grade    H       8      10
#
# ...

# %% [markdown]
# ## Synthèse des départs à la retraite

# %%
retirement_summary = get_retirement_summary(df)

retirement_summary
# Out:
#       Horizon  Nombre de départs
# 0   ≤ 1 an(s)                125
# 1   ≤ 3 an(s)                254
# 2   ≤ 5 an(s)                408
# 3  ≤ 10 an(s)                671

# %% [markdown]
# ## Départs à la retraite par grade

# %%
retirement_by_grade = get_retirement_by_grade(df, 5)

retirement_by_grade
# Out:
# grade
# Assistant Technique 1°Grade              191
# Assistant Technique 2°Grade               54
# Technicien 2°Grade                        42
# Technicien 1°Grade                        32
# Administrateur Principal                  24
# Technicien 3°Grade                        17
# Assistant Administratif 1°Grade           14
# Administrateur 1°Grade                     5
# Ingénieur en Chef Grade Principal          5
# Rédacteur 2°Grade                          5
# Assistant Technique Grade Principal        4
# Administrateur 1°Classe                    3
# Assistant Administratif 2°Grade            3
# Ingénieur en Chef 1°Grade                  3
# Rédacteur 3°Grade                          2
# Administrateur 2°Grade                     1
# Infirmier Grade Exceptionnel               1
# Professeur de Musique Adjoint 1°Grade      1
# Rédacteur 1°Grade                          1
# Name: count, dtype: int64

# %% [markdown]
# ## Départs à la retraite par sexe

# %%
retirement_by_gender = get_retirement_by_gender(df, 5)

retirement_by_gender
# Out:
# sexe
# H    328
# F     80
# Name: count, dtype: int64

# %% [markdown]
# ## Départs à la retraite par échelle

# %%
retirement_by_scale = get_retirement_by_scale(df, 5)

retirement_by_scale
# Out:
# echelle
# 6       57
# 7        0
# 8      205
# 9       23
# 10      47
# 11      75
# EXP      1
# Name: count, dtype: int64

# %% [markdown]
# # Visualisations
#
# ## Répartition des fonctionnaires par sexe

# %%
fig = create_gender_pie_chart(df)

fig.show()

# %% [markdown]
# ## Répartition des fonctionnaires par grade

# %%
fig = create_grade_bar_chart(df)

fig.show()

# %% [markdown]
# ## Répartition des fonctionnaires par échelle

# %%
fig = create_scale_bar_chart(df)

fig.show()

# %% [markdown]
# ## Répartition des fonctionnaires par échelon

# %%
fig = create_step_bar_chart(df)

fig.show()

# %% [markdown]
# ## Distribution des âges

# %%
fig = create_age_histogram(df)

fig.show()

# %% [markdown]
# ## Distribution de l'ancienneté

# %%
fig = create_seniority_histogram(df)

fig.show()

# %%
print(df["echelle"].dropna().unique())
print(df["echelon"].dropna().unique())
# Out:
# [11 'EXP' 10 8 9 6 7]
# [3 5 4 6 2 1 9 'EXP' 8 10 7 11 12]
